# %%
# !pip install numpy
# !pip install pandas
# !pip install kagglehub
# Out:
# Requirement already satisfied: numpy in .\.venv\Lib\site-packages (2.4.6)
# Requirement already satisfied: pandas in .\.venv\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in .\.venv\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os
# Requirement already satisfied: kagglehub in .\.venv\Lib\site-packages (1.0.1)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.22 in .\.venv\Lib\site-packages (from kagglehub) (0.1.23)
# Requirement already satisfied: packaging in .\.venv\Lib\site-packages (from kagglehub) (26.2)
# Requirement already satisfied: pyyaml in .\.venv\Lib\site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in .\.venv\Lib\site-packages (from kagglehub) (2.34.2)
# Requirement already satisfied: tqdm in .\.venv\Lib\site-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in .\.venv\Lib\site-packages (from kagglesdk<1.0,>=0.1.22->kagglehub) (7.35.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests->kagglehub) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\Lib\site-packages (from requests->kagglehub) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in .\.venv\Lib\site-packages (from requests->kagglehub) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in .\.venv\Lib\site-packages (from requests->kagglehub) (2026.5.20)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from tqdm->kagglehub) (0.4.6)

# %%
import numpy as np
import pandas as pd
import os
import kagglehub

# %%
#California housing dataset
path = kagglehub.dataset_download("camnugent/california-housing-prices")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\jiabi\.cache\kagglehub\datasets\camnugent\california-housing-prices\versions\1

# %%
csv_path = os.path.join(path, "housing.csv")
df = pd.read_csv(csv_path)
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
